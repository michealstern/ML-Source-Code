# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
tips_df = sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(tips_df["size"])
plt.show()

# %%
sns.histplot(tips_df["tip"])
plt.show()

# %%
sns.histplot(tips_df["total_bill"])
plt.show()

# %%
sns.histplot(tips_df["total_bill"], bins=100)
plt.show()

# %%
sns.distplot(tips_df["total_bill"], hist = True)
plt.show()
# Out:
# C:\Users\arman\AppData\Local\Temp\ipykernel_14996\2393310339.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"], hist = True)

# %%
sns.distplot(tips_df["total_bill"], kde=False)
plt.show()
# Out:
# C:\Users\arman\AppData\Local\Temp\ipykernel_14996\2193737681.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"], kde=False)

# %%
sns.distplot(tips_df["total_bill"],rug=True)
plt.show()
# Out:
# C:\Users\arman\AppData\Local\Temp\ipykernel_14996\4012690801.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],rug=True)

# %%
sns.distplot(tips_df["total_bill"], fit=norm)
plt.show()
# Out:
# C:\Users\arman\AppData\Local\Temp\ipykernel_14996\3920901372.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"], fit=norm)

# %%
sns.distplot(tips_df["total_bill"], color="r")
plt.show()
# Out:
# C:\Users\arman\AppData\Local\Temp\ipykernel_14996\2963788009.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"], color="r")

# %%
sns.distplot(tips_df["total_bill"], color="r", label="Total Bill")

plt.title("Histogram of Total Bill")
plt.legend()
plt.show()
# Out:
# C:\Users\arman\AppData\Local\Temp\ipykernel_14996\185542090.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"], color="r", label="Total Bill")

# %%
sns.set()
sns.distplot(tips_df["total_bill"], color="r", label="Total Bill")

plt.title("Histogram of Total Bill")
plt.legend()
plt.show()
# Out:
# C:\Users\arman\AppData\Local\Temp\ipykernel_14996\1054645625.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"], color="r", label="Total Bill")

# %%
bins = [1,5,10,15,20,25,30,35,40,45,50,55]

sns.set()
sns.distplot(tips_df["total_bill"], color="r", bins = bins)

plt.xticks(bins)

plt.title("Histogram of Total Bill")

plt.show()
# Out:
# C:\Users\arman\AppData\Local\Temp\ipykernel_14996\2552976819.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"], color="r", bins = bins)
